# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../data/precip-data.csv')
df.shape
# Out:
# (57, 4)

# %%
import matplotlib.pyplot as plt

plt.plot(df['Years'], df['Daily_Avg_Rate_mm/hr'])
plt.xlabel('Years')
plt.ylabel('Daily_Avg_Rate_mm/hr')
plt.show()

plt.plot(df['Years'], df['Daily_Avg_Rate_mm/hr'])
plt.xlabel('Years')
plt.ylabel('Daily_Avg_Rate_No_Zeros_mm/hr')
plt.show()
